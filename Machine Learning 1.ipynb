# %% [markdown]
# # Mechine Learning  1

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# check version

# %%
print('Versi pyhton :', sys.version[0:3])
# Out:
# Versi pyhton : 3.7

# %%
print('Versi pandas:', pd.__version__)
# Out:
# Versi pandas: 1.2.3

# %%
print('Versi numpy :', np.__version__)
# Out:
# Versi numpy : 1.19.2

# %%
print('Matplotlib:', matplotlib.__version__)
# Out:
# Matplotlib: 3.3.4

# %% [markdown]
# # Load dataset

# %%
dataset=pd.read_csv('titanic.csv')

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # Select data

# %%
select_columns=['Survived','Pclass','Name','Sex','Age','Fare']
dataset[select_columns].head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age     Fare
# 0    male  22.0   7.2500
# 1  female  38.0  71.2833
# 2  female  26.0   7.9250
# 3  female  35.0  53.1000
# 4    male  35.0   8.0500
# 5    male   NaN   8.4583
# ...

# %% [markdown]
# cek type data

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# mengubah tipe data dengan astype

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#mengisi data null dengan ffill
dataset.fillna(method='ffill', inplace=True)

# %%
dataset.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       0
# dtype: int64

# %%
dataset['Age']=dataset['Age'].astype('int64')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        890 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %%
#cek total baris kolom
print('Total row :', dataset.shape[0])
print('Total Columns :', dataset.shape[1])
# Out:
# Total row : 891
# Total Columns : 12

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.561167    0.523008
# std     257.353842    0.486592    0.836071   14.567604    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#cek null
dataset.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
dataset.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked       False
# dtype: bool

# %%
#isi cabin degan ffil
dataset['Cabin']=dataset['Cabin'].fillna(method='ffill', inplace=True)

# %%
dataset.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked       False
# dtype: bool

# %%
count =0
for x, row in dataset.iterrows():
    print('Index', x)
    print(row)
    count +=1
    
    if count ==3:
        break
# Out:
# Index 0
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                             None
# Embarked                             S
# Name: 0, dtype: object
# Index 1
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                           38
# ...

# %%
dataset.loc[20]
# Out:
# PassengerId                      21
# Survived                          0
# Pclass                            2
# Name           Fynney, Mr. Joseph J
# Sex                            male
# Age                              35
# SibSp                             0
# Parch                             0
# Ticket                       239865
# Fare                           26.0
# Cabin                          None
# Embarked                          S
# Name: 20, dtype: object

# %%
dataset.groupby('Sex').agg('mean')
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  28.417197  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.183709  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %% [markdown]
# # plot sederhana

# %%
dataset.groupby('Pclass').sum().plot(kind='bar');

# %%
dataset.groupby('Age').sum().reset_index()
# Out:
#     Age  PassengerId  Survived  Pclass  SibSp  Parch      Fare
# 0     0         5503         8      23      7      9  386.1958
# 1     1         3737         6      22     13     11  217.7917
# 2     2         6615         6      41     21     13  546.0333
# 3     3         2008         6      16     12      8  236.8625
# 4     4         5858        10      37     18     15  460.3957
# ..  ...          ...       ...     ...    ...    ...       ...
# 66   66           34         0       2      0      0   10.5000
# 67   70         1536         0       6      1      1   89.2500
# 68   71          591         0       2      0      0   84.1584
# 69   74          852         0       3      0      0    7.7750
# 70   80          631         1       1      0      0   30.0000
#
# [71 rows x 7 columns]

# %% [markdown]
# # concatenate data

# %% [markdown]
# menggabungkan kolom

# %%
data1=dataset[['Survived','Pclass']]
data2=dataset[['Sex']]
data3=dataset[['Fare']]

# %%
data1
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]

# %%
data2
# Out:
#         Sex
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# ..      ...
# 886    male
# 887  female
# 888  female
# 889    male
# 890    male
#
# [891 rows x 1 columns]

# %%
data3
# Out:
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
# 890   7.7500
#
# [891 rows x 1 columns]

# %%
dataset2=pd.concat([data1,data2,data3], axis=1)

# %%
dataset2
# Out:
#      Survived  Pclass     Sex     Fare
# 0           0       3    male   7.2500
# 1           1       1  female  71.2833
# 2           1       3  female   7.9250
# 3           1       1  female  53.1000
# 4           0       3    male   8.0500
# ..        ...     ...     ...      ...
# 886         0       2    male  13.0000
# 887         1       1  female  30.0000
# 888         0       3  female  23.4500
# 889         1       1    male  30.0000
# 890         0       3    male   7.7500
#
# [891 rows x 4 columns]

# %% [markdown]
# save csv

# %%
dataset2.to_csv('datasetbaru.csv')

# %%
dataset3=pd.read_csv('datasetbaru.csv')

# %%
dataset3
# Out:
#      Unnamed: 0  Survived  Pclass     Sex     Fare
# 0             0         0       3    male   7.2500
# 1             1         1       1  female  71.2833
# 2             2         1       3  female   7.9250
# 3             3         1       1  female  53.1000
# 4             4         0       3    male   8.0500
# ..          ...       ...     ...     ...      ...
# 886         886         0       2    male  13.0000
# 887         887         1       1  female  30.0000
# 888         888         0       3  female  23.4500
# 889         889         1       1    male  30.0000
# 890         890         0       3    male   7.7500
#
# [891 rows x 5 columns]

# %% [markdown]
# # Change Columns

# %%
kolombaru={'Survived':'SURVIVED','Pclass':'PCLASS'}

# %%
dataset4=dataset3.rename(columns=kolombaru)

# %%
dataset4.head()
# Out:
#    Unnamed: 0  SURVIVED  PCLASS     Sex     Fare
# 0           0         0       3    male   7.2500
# 1           1         1       1  female  71.2833
# 2           2         1       3  female   7.9250
# 3           3         1       1  female  53.1000
# 4           4         0       3    male   8.0500
